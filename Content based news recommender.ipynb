# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", None, "display.max_columns", None)
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # **Load data**

# %%
# Dữ liệu là các bài báo gồm có 3 feature là:
# Title: tiêu đề bài báo
# Sapo: tiêu đề phụ
# Body: phần nội dung báo

title, sapo, body = [], [], []
path_file = '/content/gdrive/MyDrive/Data Science/Recommendation system/News Recommendation /Data/'
for filename in os.listdir(path_file):
  with open(path_file + filename, 'r') as file_in:
    count = 0
    content = ''
    for line in file_in:
      if count == 0:
        title.append(line[:-1])
        count = count + 1
      elif count == 1:
        sapo.append(line[:-1])
        count = count + 1
      else:
        content = content + line[:-1]
    body.append(content)

# %%
print('Lenght of title:', len(title))
print('Lenght of sapo:', len(sapo))
print('Lenght of body:', len(body))
# Out:
# Lenght of title: 4419
# Lenght of sapo: 4419
# Lenght of body: 4419

# %% [markdown]
# ## Create dataframe

# %%
df_news = pd.DataFrame({'title': title, 'sapo': sapo, 'body': body})
df_news.drop_duplicates(inplace=True)
df_news.dropna(inplace=True)
df_news.insert(0, 'id', np.arange(len(df_news)))
df_news.head()
# Out:
#    id                                              title  \
# 0   0  Ly hôn chồng cũ 6 năm, vợ trẻ vẫn hoảng sợ vì ...
# 1   1  Sẽ cưỡng chế tháo dỡ công trình 'xẻ thịt' rừng...
# 2   2          Va chạm với xe tải, một nữ sinh nguy kịch
# 3   3                 Nhà văn Kim Dung qua đời ở tuổi 94
# 4   4  12.000 vụ án và 2.000 bị can đang bị treo lơ l...
#
#                                                 sapo  \
# 0  Suốt 6 năm qua chị liên tục nhận được những ti...
# 1  'Thông báo để các hộ dân tự tháo dỡ, nếu không...
# 2  Đang trên đường rẽ vào đền Quả Sơn chiếc xe tả...
# 3  Nhà văn Kim Dung, tác giả của hàng loạt tác ph...
# 4  Sáng nay (30/10), chất vấn tại Hội trường, ĐB ...
#
#                                                 body
# 0  Nhiều người nói rằng phụ nữ lấy chồng chẳng kh...
# 1  Tờ Zing.vn đưa tin, sáng 30/10, Chủ tịch UBND ...
# 2  Tối 30/10, Công an huyện Đô Lương (Nghệ An) ch...
# 3  Theo thông tin được các báo Hoa ngữ đăng tải, ...
# 4  Nguyên nhân chủ quan chiếm tỷ lệ rất nhỏDẫn bá...

# %%
df_news.shape
# Out:
# (3616, 4)

# %% [markdown]
# #**Encoding data by IF-IDF**

# %% [markdown]
# ## Importing Liberaries

# %%
# !pip install pyvi
# Out:
# Collecting pyvi
#   Downloading https://files.pythonhosted.org/packages/10/e1/0e5bc6b5e3327b9385d6e0f1b0a7c0404f28b74eb6db59a778515b30fd9c/pyvi-0.1-py2.py3-none-any.whl (8.5MB)
#      |████████████████████████████████| 8.5MB 16.4MB/s
# Collecting sklearn-crfsuite
#   Downloading https://files.pythonhosted.org/packages/25/74/5b7befa513482e6dee1f3dd68171a6c9dfc14c0eaa00f885ffeba54fe9b0/sklearn_crfsuite-0.3.6-py2.py3-none-any.whl
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyvi) (0.22.2.post1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (0.8.9)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (1.15.0)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (4.41.1)
# Collecting python-crfsuite>=0.8.3
#   Downloading https://files.pythonhosted.org/packages/79/47/58f16c46506139f17de4630dbcfb877ce41a6355a1bbf3c443edb9708429/python_crfsuite-0.9.7-cp37-cp37m-manylinux1_x86_64.whl (743kB)
#      |████████████████████████████████| 747kB 46.8MB/s
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.0.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.19.5)
# Installing collected packages: python-crfsuite, sklearn-crfsuite, pyvi
# Successfully installed python-crfsuite-0.9.7 pyvi-0.1 sklearn-crfsuite-0.3.6

# %%
from pyvi import ViTokenizer
import string
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ## Preprocessing

# %%
def make_lowercase(text):
  """
  Chuyển chữ hoa của text về chữ thường
  """
  return text.lower()

def remove_punctuation(text):
  """
  Xóa các dấu câu trong text
  """
  return re.sub('['+string.punctuation+']', ' ', text)

def tokenizer(text):
  """
  Tách text VD: tôi thích ăn bánh quy -> tôi thích ăn bánh_quy 
  """
  return ViTokenizer.tokenize(text)

def remove_stopwords(text):
  """
  Xóa stopwords và số
  """
  text = text.split()
  stopwords = ['bị', 'bởi', 'cả', 'các', 'cái', 'cần', 'càng', 'chỉ', 'chiếc', 'cho', 'chứ', 'chưa', 'chuyện', 
             'có', 'có_thể', 'cứ', 'của', 'cùng', 'cũng', 'đã', 'đang', 'đây', 'để', 'đến_nỗi', 'đều', 'điều', 
             'do', 'đó', 'được', 'dưới', 'gì', 'khi', 'không', 'là', 'lại', 'lên', 'lúc', 'mà', 'mỗi', 'một_cách', 
             'này', 'nên', 'nếu', 'ngay', 'nhiều', 'như', 'nhưng', 'những', 'nơi', 'nữa', 'phải', 'qua', 'ra', 
             'rằng', 'rằng', 'rất', 'rất', 'rồi', 'sau', 'sẽ', 'so', 'sự', 'tại', 'theo', 'thì', 'trên', 'trước', 
             'từ', 'từng', 'và', 'vẫn', 'vào', 'vậy', 'vì', 'việc', 'với', 'vừa']
  text = [w for w in text if not w in stopwords]
  texts = [w for w in text if not w.isdigit()]
  texts = " ".join(texts)
  return texts

df_news['body_cleaned'] = df_news['body'].apply(func=make_lowercase)
df_news['body_cleaned'] = df_news['body_cleaned'].apply(func=remove_punctuation)
df_news['body_cleaned'] = df_news['body_cleaned'].apply(func=tokenizer)
df_news['body_cleaned'] = df_news['body_cleaned'].apply(func=remove_stopwords)

# %%
df_news.head()
# Out:
#    id                                              title  \
# 0   0  Ly hôn chồng cũ 6 năm, vợ trẻ vẫn hoảng sợ vì ...
# 1   1  Sẽ cưỡng chế tháo dỡ công trình 'xẻ thịt' rừng...
# 2   2          Va chạm với xe tải, một nữ sinh nguy kịch
# 3   3                 Nhà văn Kim Dung qua đời ở tuổi 94
# 4   4  12.000 vụ án và 2.000 bị can đang bị treo lơ l...
#
#                                                 sapo  \
# 0  Suốt 6 năm qua chị liên tục nhận được những ti...
# 1  'Thông báo để các hộ dân tự tháo dỡ, nếu không...
# 2  Đang trên đường rẽ vào đền Quả Sơn chiếc xe tả...
# 3  Nhà văn Kim Dung, tác giả của hàng loạt tác ph...
# 4  Sáng nay (30/10), chất vấn tại Hội trường, ĐB ...
#
#                                                 body  \
# 0  Nhiều người nói rằng phụ nữ lấy chồng chẳng kh...
# 1  Tờ Zing.vn đưa tin, sáng 30/10, Chủ tịch UBND ...
# 2  Tối 30/10, Công an huyện Đô Lương (Nghệ An) ch...
# 3  Theo thông tin được các báo Hoa ngữ đăng tải, ...
# 4  Nguyên nhân chủ quan chiếm tỷ lệ rất nhỏDẫn bá...
#
#                                         body_cleaned
# 0  người nói phụ_nữ lấy chồng chẳng khác_nào canh...
# 1  tờ zing vn đưa tin sáng chủ_tịch ubnd tp hà_nộ...
# 2  tối công_an huyện đô lương nghệ_an biết địa_bà...
# 3  thông_tin báo hoa ngữ đăng_tải kim dung mất bệ...
# 4  nguyên_nhân chủ_quan chiếm tỷ_lệ nhỏdẫn báo_cá...

# %% [markdown]
# ## TF-IDF

# %%
vectorizer = TfidfVectorizer(max_df=0.8, use_idf=True, ngram_range=(1,3))
tfidf_matrix = vectorizer.fit_transform(df_news['body_cleaned'])

# %% [markdown]
# # **Similarity between vectors**

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_score = cosine_similarity(tfidf_matrix)
cosine_score
# Out:
# array([[1.        , 0.00437835, 0.00732384, ..., 0.00856488, 0.00828742,
#         0.00725494],
#        [0.00437835, 1.        , 0.01371953, ..., 0.00252481, 0.00582427,
#         0.02857087],
#        [0.00732384, 0.01371953, 1.        , ..., 0.0021417 , 0.00365852,
#         0.0100892 ],
#        ...,
#        [0.00856488, 0.00252481, 0.0021417 , ..., 1.        , 0.00186422,
#         0.00495717],
#        [0.00828742, 0.00582427, 0.00365852, ..., 0.00186422, 1.        ,
#         0.00578285],
#        [0.00725494, 0.02857087, 0.0100892 , ..., 0.00495717, 0.00578285,
#         1.        ]])

# %%
cosine_score.shape
# Out:
# (3616, 3616)

# %% [markdown]
# # **Recommendation**

# %%
def get_information(id):
  print("ID        :    ", df_news.iloc[id]['id'])
  print("Title     :    ", df_news.iloc[id]['title'])
  print("Sapo      :    ", df_news.iloc[id]['sapo'])

def recommender(id, k):
  """
  id: id của bài báo
  k: top k item cần recommender
  """
  similar_indices = cosine_score[id].argsort()[-(k+1):-1]
  get_information(id)
  print("-"*100)
  count = 1
  for i in range(k-1, -1, -1):
    print("Recommendation",count)
    get_information(similar_indices[i])
    print("Similarity:", cosine_score[id][similar_indices[i]])
    print("-"*100)
    count = count + 1

# %%
recommender(10, 5)
# Out:
# ID        :     10
# Title     :     Lo lắng về sự xuống cấp của đạo đức xã hội
